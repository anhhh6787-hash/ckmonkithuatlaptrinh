# %%
str_data = 'X-DSPAM-Confidence:0.8475'

type = str_data.find(':')

number = str_data[type + 1:]

result = float(number)

print(result)
# Out:
# 0.8475

# %%
text = "  Hello, World!  "
print(text.strip())        
email = "user@hunganh.com"
print(email.replace("hunganh", "hha"))
# Out:
# Hello, World!
# user@hha.com
