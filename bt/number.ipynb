# %%
str='       HELLO PYTHON'
delete=str.strip() # xóa khoảng trống đầu
print(str)
# Out:
#        HELLO PYTHON

# %%
str1='I LIKE ENGLISH'
str2=str1.replace("ENGLISH","VIETNAM")
print(str2)
# Out:
# I LIKE VIETNAM

# %%
str3='      HELLO HUYNH TU'
delete=str3.strip()
delete1=delete.replace("TU","ANH")
print(delete1)
# Out:
# HELLO HUYNH ANH
